# %%
# !git clone https://github.com/CVMI-Lab/SyntheticData.git
# Out:
# fatal: destination path 'SyntheticData' already exists and is not an empty directory.

# %%
# !pip install -r /content/SyntheticData/requirements.txt
# Out:
# ...
#   Using cached robustness-1.2.1.post2-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached GPUtil-1.4.0.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached tensorboardx-2.6.5-py3-none-any.whl.metadata (6.6 kB)
# ...
#   Using cached jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# ...
#   Using cached cox-0.2-py3-none-any.whl.metadata (17 kB)
# ...
#   Using cached sklearn-0.0.post12.tar.gz (2.6 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# !pip install keytotext

# %%
# !python /content/SyntheticData/src/LE_update.py 30 /content/issynth_eurosat.pkl
# Out:
# Using device: cuda
# ...
# Loading weights: 100% 260/260 [00:00<00:00, 5226.35it/s]
# [transformers] The tied weights mapping and config for this model specifies to tie shared.weight to lm_head.weight, but both are present in the checkpoints with different values, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning.
#
# Generating: annual crop land
# Attempts: 10, Unique: 10/30
# Attempts: 20, Unique: 20/30
# Attempts: 30, Unique: 30/30
# Finished annual crop land: 30 unique sentences
#
# Generating: forest
# Attempts: 10, Unique: 10/30
# Attempts: 20, Unique: 20/30
# Attempts: 30, Unique: 30/30
# Finished forest: 30 unique sentences
#
# Generating: herbaceous vegetation land
# Attempts: 10, Unique: 10/30
# Attempts: 20, Unique: 20/30
# Attempts: 30, Unique: 30/30
# Finished herbaceous vegetation land: 30 unique sentences
#
# Generating: highway or road
# Attempts: 10, Unique: 10/30
# Attempts: 20, Unique: 20/30
# ...

# %%
import pickle

path = "/content/issynth_eurosat.pkl"

with open(path, "rb") as f:
    data = pickle.load(f)

print(type(data))
print(data)
# Out:
# <class 'dict'>
# ...

# %%
data['sea or lake'][:10]
# Out:
# ['floating in the sea or lake .',
#  'a fishing boat parked in a lake or sea',
#  'the waters over sea or lake',
#  'the sea or lake',
#  'a lonely man in water by a lake or sea',
#  'the sea or a lake',
#  'the blue sea or lake with the large cliffs',
#  'sea of the sea or lake',
#  'a lake or the sea of the mangrove forest',
#  'the sea or lake in the distance']
